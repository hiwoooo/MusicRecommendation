# %% [markdown]
# # 이미지 변환
# - 이미지 cnn 결과 val acc가 오르지 않는 문제 직면.
# -  jpg파일, pixel numpy array로 변환하여 저장

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt

# %%
import os 
import cv2
from sklearn import utils # sklearn의 shuffle과 같은 기능 사용
from tqdm.notebook import tqdm

# %%
from google.colab.patches import cv2_imshow

# %%
fer2013=pd.read_csv('/content/drive/MyDrive/final/data/fer2013.csv')
fer2013.head()
len(fer2013)
# Out:
# 35887

# %%
fer2013.Usage.value_counts()
# Out:
# Training       28709
# PublicTest      3589
# PrivateTest     3589
# Name: Usage, dtype: int64

# %%
print(fer2013.pixels[0])
print(type(fer2013.pixels[0]))
# Out:
# 70 80 82 72 58 58 60 63 54 58 60 48 89 115 121 119 115 110 98 91 84 84 90 99 110 126 143 153 158 171 169 172 169 165 129 110 113 107 95 79 66 62 56 57 61 52 43 41 65 61 58 57 56 69 75 70 65 56 54 105 146 154 151 151 155 155 150 147 147 148 152 158 164 172 177 182 186 189 188 190 188 180 167 116 95 103 97 77 72 62 55 58 54 56 52 44 50 43 54 64 63 71 68 64 52 66 119 156 161 164 163 164 167 168 170 174 175 176 178 179 183 187 190 195 197 198 197 198 195 191 190 145 86 100 90 65 57 60 54 51 41 49 56 47 38 44 63 55 46 52 54 55 83 138 157 158 165 168 172 171 173 176 179 179 180 182 185 187 189 189 192 197 200 199 196 198 200 198 197 177 91 87 96 58 58 59 51 42 37 41 47 45 37 35 36 30 41 47 59 94 141 159 161 161 164 170 171 172 176 178 179 182 183 183 187 189 192 192 194 195 200 200 199 199 200 201 197 193 111 71 108 69 55 61 51 42 43 56 54 44 24 29 31 45 61 72 100 136 150 159 163 162 163 170 172 171 174 177 177 180 187 186 187 189 192 192 194 195 196 197 199 200 201 200 197 201 137 58 98 92 57 62 53 47 41 40 51 43 24 35 52 63 75 104 129 143 149 158 162 164 166 171 173 172 174 178 178 179 187 188 188 191 193 194 195 198 199 199 197 198 197 197 197 201 164 52 78 87 69 58 56 50 54 39 44 42 26 31 49 65 91 119 134 145 147 152 159 163 167 171 170 169 174 178 178 179 187 187 185 187 190 188 187 191 197 201 199 199 200 197 196 197 182 58 62 77 61 60 55 49 59 52 54 44 22 30 47 68 102 123 136 144 148 150 153 157 167 172 173 170 171 177 179 178 186 190 186 189 196 193 191 194 190 190 192 197 201 203 199 194 189 69 48 74 56 60 57 50 59 59 51 41 20 34 47 79 111 132 139 143 145 147 150 151 160 169 172 171 167 171 177 177 174 180 182 181 192 196 189 192 198 195 194 196 198 201 202 195 189 70 39 69 61 61 61 53 59 59 45 40 26 40 61 93 124 135 138 142 144 146 151 152 158 165 168 168 165 161 164 173 172 167 172 167 180 198 198 193 199 195 194 198 200 198 197 195 190 65 35 68 59 59 62 57 60 59 50 44 32 54 90 115 132 137 138 140 144 146 146 156 165 168 174 176 176 175 168 168 169 171 175 171 172 192 194 184 198 205 201 194 195 193 195 192 186 57 38 72 65 57 62 58 57 60 54 49 47 79 116 130 138 141 141 139 141 143 145 157 164 164 166 173 174 176 179 179 176 181 189 188 173 180 175 160 182 189 198 192 189 190 190 188 172 46 44 64 66 59 62 57 56 62 53 50 66 103 133 137 141 143 141 136 132 131 136 127 118 111 107 108 123 131 143 154 158 166 177 181 175 170 159 148 171 161 176 185 192 194 188 190 162 53 49 58 63 61 61 55 56 61 51 50 81 116 139 142 142 146 144 136 128 119 112 97 85 90 91 88 92 90 80 81 84 106 122 132 144 145 144 147 163 147 163 173 181 190 187 191 167 61 48 53 61 61 58 54 56 61 51 53 89 123 140 144 145 146 147 136 122 107 99 95 92 90 87 83 76 67 52 46 52 63 69 83 96 119 132 148 159 136 137 143 138 143 152 156 156 70 48 50 59 61 57 54 54 61 52 56 93 124 135 140 144 148 150 140 125 114 101 80 54 56 54 41 41 33 40 39 35 49 60 63 74 107 129 147 147 116 111 100 77 76 86 108 111 73 49 50 60 62 60 57 55 63 59 56 89 121 134 139 146 151 152 150 141 127 111 96 77 85 70 32 31 37 91 65 50 48 59 73 83 112 136 155 130 60 46 38 40 43 81 116 91 72 52 48 58 62 62 59 53 61 59 52 85 114 134 140 147 154 159 158 153 145 143 150 126 121 125 68 45 89 137 95 70 78 75 95 109 131 153 171 94 23 16 32 82 82 65 113 77 71 54 48 56 62 62 60 53 60 56 52 75 108 133 141 149 158 166 169 167 163 156 155 146 112 119 134 127 142 140 121 117 129 114 120 129 146 174 191 98 46 33 33 109 147 98 109 67 73 55 50 56 64 64 61 58 61 53 54 64 106 129 140 148 159 169 175 176 174 165 159 156 145 120 115 124 127 131 133 141 147 142 141 147 161 182 202 154 114 96 100 158 158 153 123 61 76 57 48 56 64 64 63 62 61 54 55 44 97 131 137 147 158 168 177 181 183 179 170 168 169 165 155 152 151 152 154 162 165 158 153 158 168 187 206 186 147 135 144 145 152 178 115 57 74 58 48 58 64 63 63 59 63 55 53 66 104 130 132 144 153 162 170 180 185 187 181 178 182 180 177 173 171 171 177 176 172 164 161 167 164 185 207 197 173 152 141 141 161 191 104 54 69 60 48 57 65 62 60 57 64 55 50 94 111 124 130 135 150 159 ...
# <class 'str'>

# %% [markdown]
# - 기존 fer2013.csv에서 pixel 항목과 같은 형식의 데이터로 변환
#   - (48,48)배열을 하나의 문자열로

# %%
def showImg_label(x,y):
  x_reshaped=x.reshape(48,48)
  plt.imshow(x_reshaped, cmap='gray', interpolation='nearest') #고해상도 보간법
  plt.axis('off')
  plt.show()
  print(y)

# %%
img=fer2013['pixels'][15]
val=img.split(" ")
x_pixels=np.array(val, 'float32')
x_pixels /= 255

# %%
showImg_label(x_pixels, fer2013['emotion'][15])
# Out:
# 5

# %% [markdown]
# ## sample

# %%
train_dir='/content/drive/MyDrive/final/data/AIHub/train/surprise'

# %%
surprise_names=os.listdir(train_dir)
len(surprise_names)
# Out:
# 3197

# %%
sample_path= os.path.join(train_dir,'3100.jpg') 
sample_path
# Out:
# '/content/drive/MyDrive/final/data/AIHub/train/surprise/3100.jpg'

# %%
sample_img=cv2.imread(sample_path, cv2.IMREAD_GRAYSCALE)
# 0         5.0  10 8 7 9 10 21 25 37 39 34 45 82 82 82 88 93 9...
# 1         5.0  69 78 83 92 97 107 124 119 58 32 62 79 106 157...
# 2         5.0  219 217 218 218 224 151 59 75 51 50 107 163 14...
# 3         5.0  254 253 255 254 255 255 250 101 33 54 73 74 64...
# 4         5.0  99 98 82 78 69 56 53 55 51 52 58 67 83 110 118...
# ...       ...                                                ...
# 3192      5.0  195 196 177 179 110 37 51 58 68 83 87 83 81 80...
# 3193      5.0  250 251 249 250 254 249 251 247 255 164 0 28 1...
# 3194      5.0  145 158 164 129 74 47 54 64 54 72 91 104 114 1...
# 3195      5.0  9 38 69 99 86 102 111 105 65 58 64 49 41 39 35...
# 3196      5.0  157 161 163 166 165 161 168 164 167 181 198 19...
#
# [3197 rows x 2 columns]

# %% [markdown]
# ## Happy, Sad, Neutral

# %%
base_dir='/content/drive/MyDrive/final/data/AIHub/train'
happy_path=os.path.join(base_dir, 'happiness')
sad_path=os.path.join(base_dir, 'sadness')
neutral_path=os.path.join(base_dir, 'neutral')

# %%
happy_names=os.listdir(happy_path)
sad_names=os.listdir(sad_path)
neutral_names=os.listdir(neutral_path)

# %%
emotion_label = {'happiness':3 ,  'sadness' :4 , 'neutral' :6}

# %%
emotion_label['happiness']
# Out:
# 3

# %%
def fill_data(emotion_path, emotion_names,label):
  global data
  for name in emotion_names:
      img_path = os.path.join(emotion_path,name) 
      img_data = cv2.resize(cv2.imread(img_path, cv2.IMREAD_GRAYSCALE), (48,48))
      img_pix=list(img_data.ravel())
      img_pix=' '.join(str(s) for s in img_pix)
      data_to_insert = {'emotion': label, 'pixels' : img_pix}
      data=data.append(data_to_insert, ignore_index=True)

# %%
fill_data(happy_path, happy_names, 3)

# %%
data
# Out:
#        emotion                                             pixels
# 0          5.0  10 8 7 9 10 21 25 37 39 34 45 82 82 82 88 93 9...
# 1          5.0  69 78 83 92 97 107 124 119 58 32 62 79 106 157...
# 2          5.0  219 217 218 218 224 151 59 75 51 50 107 163 14...
# 3          5.0  254 253 255 254 255 255 250 101 33 54 73 74 64...
# 4          5.0  99 98 82 78 69 56 53 55 51 52 58 67 83 110 118...
# ...        ...                                                ...
# 10487      3.0  45 61 57 39 63 94 124 141 141 157 161 170 178 ...
# 10488      3.0  133 157 184 208 212 207 206 210 206 197 176 15...
# 10489      3.0  139 130 138 132 128 112 90 88 79 103 119 137 1...
# 10490      3.0  197 196 200 194 199 149 119 119 105 95 108 109...
# 10491      3.0  178 212 191 164 155 164 162 111 116 138 155 17...
#
# [10492 rows x 2 columns]

# %%
fill_data(sad_path, sad_names, 4)
fill_data(neutral_path, neutral_names, 6)

# %%
data
# Out:
#        emotion                                             pixels
# 0          5.0  10 8 7 9 10 21 25 37 39 34 45 82 82 82 88 93 9...
# 1          5.0  69 78 83 92 97 107 124 119 58 32 62 79 106 157...
# 2          5.0  219 217 218 218 224 151 59 75 51 50 107 163 14...
# 3          5.0  254 253 255 254 255 255 250 101 33 54 73 74 64...
# 4          5.0  99 98 82 78 69 56 53 55 51 52 58 67 83 110 118...
# ...        ...                                                ...
# 20292      6.0  47 53 84 119 93 62 51 56 52 56 56 56 57 57 57 ...
# 20293      6.0  30 23 25 21 28 36 50 77 97 104 110 113 119 127...
# 20294      6.0  42 31 6 6 0 3 3 0 0 0 10 71 133 169 187 198 20...
# 20295      6.0  220 221 195 129 122 128 131 123 126 135 140 14...
# 20296      6.0  118 24 15 16 34 31 56 85 87 89 90 103 106 112 ...
#
# [20297 rows x 2 columns]

# %%
data.to_csv('/content/drive/MyDrive/final/data/emotion.csv', index=False)

# %%
df=pd.read_csv('/content/drive/MyDrive/final/data/emotion_data2.csv')
df
# Out:
#        emotion                                             pixels
# 0          5.0  10 8 7 9 10 21 25 37 39 34 45 82 82 82 88 93 9...
# 1          5.0  69 78 83 92 97 107 124 119 58 32 62 79 106 157...
# 2          5.0  219 217 218 218 224 151 59 75 51 50 107 163 14...
# 3          5.0  254 253 255 254 255 255 250 101 33 54 73 74 64...
# 4          5.0  99 98 82 78 69 56 53 55 51 52 58 67 83 110 118...
# ...        ...                                                ...
# 20292      6.0  47 53 84 119 93 62 51 56 52 56 56 56 57 57 57 ...
# 20293      6.0  30 23 25 21 28 36 50 77 97 104 110 113 119 127...
# 20294      6.0  42 31 6 6 0 3 3 0 0 0 10 71 133 169 187 198 20...
# 20295      6.0  220 221 195 129 122 128 131 123 126 135 140 14...
# 20296      6.0  118 24 15 16 34 31 56 85 87 89 90 103 106 112 ...
#
# [20297 rows x 2 columns]

# %%
df.emotion.value_counts()
# Out:
# 3.0    7295
# 6.0    4966
# 4.0    4839
# 5.0    3197
# Name: emotion, dtype: int64

# %% [markdown]
# # DCNN

# %%
from matplotlib import pyplot

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from keras.utils import np_utils
import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, BatchNormalization, LeakyReLU, Activation
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
img_array = df.pixels.apply(lambda x: np.array(x.split(' ')).reshape(48, 48, 1).astype('float32'))
img_array = np.stack(img_array, axis=0)

# %%
le = LabelEncoder()
img_labels = le.fit_transform(df['emotion'])
img_labels = np_utils.to_categorical(img_labels)
img_labels.shape
# Out:
# (20297, 4)

# %%
le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(le_name_mapping)
# Out:
# {3.0: 0, 4.0: 1, 5.0: 2, 6.0: 3}

# %%
X_train, X_test, y_train, y_test = train_test_split(img_array, img_labels,
                                                    shuffle=True, stratify=img_labels,
                                                    test_size=0.2, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((16237, 48, 48, 1), (4060, 48, 48, 1), (16237, 4), (4060, 4))

# %%
img_width = X_train.shape[1]
img_height = X_train.shape[2]
img_depth = X_train.shape[3]
num_classes = y_train.shape[1]

# %%
X_train = X_train / 255.
X_test = X_test / 255.

# %% [markdown]
# - 네트워크 구성

# %%
def build_net5(optim):
            net = Sequential(name='DCNN')

            net.add(Conv2D(filters=128, kernel_size=(5,5),input_shape=(img_width, img_height, img_depth),activation='elu',
                           padding='same',kernel_initializer='he_normal', name='conv2d_1'))
            net.add(BatchNormalization(name='batchnorm_1'))
            net.add(Conv2D(filters=128, kernel_size=(5,5),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_2'))
            net.add(BatchNormalization(name='batchnorm_2'))
            net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_1'))
            net.add(Dropout(0.3, name='dropout_1'))

            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_3'))
            net.add(BatchNormalization(name='batchnorm_3'))
            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_4'))
            net.add(BatchNormalization(name='batchnorm_4'))
            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_7'))
            net.add(BatchNormalization(name='batchnorm_7'))           
            net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_2'))
            net.add(Dropout(0.4, name='dropout_2'))

            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_5'))
            net.add(BatchNormalization(name='batchnorm_5'))
            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_6'))
            net.add(BatchNormalization(name='batchnorm_6'))
            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_8'))
            net.add(BatchNormalization(name='batchnorm_8'))            
            net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_3'))
            net.add(Dropout(0.4, name='dropout_3'))

            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_9'))
            net.add(BatchNormalization(name='batchnorm_10'))
            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_10'))
            net.add(BatchNormalization(name='batchnorm_11'))
            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='relu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_11'))
            net.add(BatchNormalization(name='batchnorm_12'))            
            net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_4'))
            net.add(Dropout(0.5, name='dropout_4'))            


            net.add(Flatten(name='flatten'))
            net.add(Dense(128,activation='elu',kernel_initializer='he_normal',name='dense_1'))
            net.add(BatchNormalization(name='batchnorm_9'))
            net.add(Dropout(0.6, name='dropout_5'))
            net.add(Dense(num_classes,activation='softmax',name='out_layer'))

            net.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

            net.summary()

            
            return net

# %%
early_stopping = EarlyStopping(monitor='val_accuracy',min_delta=0.00005,patience=10,verbose=1,
    restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_accuracy',factor=0.5,patience=7,min_lr=1e-7,verbose=1)

callbacks = [early_stopping,lr_scheduler]

# %% [markdown]
# - 증식

# %%
train_datagen = ImageDataGenerator(rotation_range=15,width_shift_range=0.15,height_shift_range=0.15,
    shear_range=0.15,zoom_range=0.15,horizontal_flip=True)
train_datagen.fit(X_train)

# %%
batch_size = 64 
epochs = 100
optims = [optimizers.Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, name='Nadam')
          ,optimizers.Adam(0.001)]

model5 = build_net5(optims[1]) 
history = model5.fit(train_datagen.flow(X_train, y_train, batch_size=batch_size),validation_data=(X_test, y_test),
    steps_per_epoch=len(X_train) / batch_size,epochs=epochs,callbacks=callbacks)
# Out:
# Model: "DCNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 48, 48, 128)       3328
#
#  batchnorm_1 (BatchNormaliza  (None, 48, 48, 128)      512
#  tion)
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       409728
#
#  batchnorm_2 (BatchNormaliza  (None, 48, 48, 128)      512
#  tion)
#
#  maxpool2d_1 (MaxPooling2D)  (None, 24, 24, 128)       0
#
#  dropout_1 (Dropout)         (None, 24, 24, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 256)       295168
#
#  batchnorm_3 (BatchNormaliza  (None, 24, 24, 256)      1024
#  tion)
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 256)       590080
#
#  batchnorm_4 (BatchNormaliza  (None, 24, 24, 256)      1024
#  tion)
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 256)       590080
#
#  batchnorm_7 (BatchNormaliza  (None, 24, 24, 256)      1024
#  tion)
#
#  maxpool2d_2 (MaxPooling2D)  (None, 12, 12, 256)       0
#
#  dropout_2 (Dropout)         (None, 12, 12, 256)       0
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 256)       590080
#
#  batchnorm_5 (BatchNormaliza  (None, 12, 12, 256)      1024
#  tion)
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 256)       590080
#
#  batchnorm_6 (BatchNormaliza  (None, 12, 12, 256)      1024
#  tion)
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 256)       590080
#
#  batchnorm_8 (BatchNormaliza  (None, 12, 12, 256)      1024
#  tion)
#
#  maxpool2d_3 (MaxPooling2D)  (None, 6, 6, 256)         0
#
#  dropout_3 (Dropout)         (None, 6, 6, 256)         0
#
#  conv2d_9 (Conv2D)           (None, 6, 6, 256)         590080
#
#  batchnorm_10 (BatchNormaliz  (None, 6, 6, 256)        1024
#  ation)
#
#  conv2d_10 (Conv2D)          (None, 6, 6, 256)         590080
#
#  batchnorm_11 (BatchNormaliz  (None, 6, 6, 256)        1024
#  ation)
#
#  conv2d_11 (Conv2D)          (None, 6, 6, 256)         590080
#
#  batchnorm_12 (BatchNormaliz  (None, 6, 6, 256)        1024
#  ation)
#
#  maxpool2d_4 (MaxPooling2D)  (None, 3, 3, 256)         0
#
#  dropout_4 (Dropout)         (None, 3, 3, 256)         0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  d
100
# 253/253 [==============================] - 16s 65ms/step - loss: 0.1443 - accuracy: 0.8886 - val_loss: 0.2684 - val_accuracy: 0.8049 - lr: 5.0000e-04
# Epoch 48/100
# 253/253 [==============================] - 16s 65ms/step - loss: 0.1412 - accuracy: 0.8909 - val_loss: 0.2491 - val_accuracy: 0.8172 - lr: 5.0000e-04
# Epoch 49/100
# 254/253 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.8930
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 253/253 [==============================] - 17s 65ms/step - loss: 0.1403 - accuracy: 0.8930 - val_loss: 0.2390 - val_accuracy: 0.8121 - lr: 5.0000e-04
# Epoch 50/100
# 253/253 [==============================] - 16s 65ms/step - loss: 0.1327 - accuracy: 0.9019 - val_loss: 0.2535 - val_accuracy: 0.8111 - lr: 2.5000e-04
# Epoch 51/100
# 253/253 [==============================] - 17s 65ms/step - loss: 0.1264 - accuracy: 0.9079 - val_loss: 0.2526 - val_accuracy: 0.8153 - lr: 2.5000e-04
# Epoch 52/100
# 254/253 [==============================] - ETA: 0s - loss: 0.1200 - accuracy: 0.9087Restoring model weights from the end of the best epoch: 42.
# 253/253 [==============================] - 17s 65ms/step - loss: 0.1200 - accuracy: 0.9087 - val_loss: 0.2574 - val_accuracy: 0.8145 - lr: 2.5000e-04
# Epoch 52: early stopping

# %%
result= model5.evaluate(X_test, y_test)
# Out:
# 127/127 [==============================] - 2s 14ms/step - loss: 0.2332 - accuracy: 0.8209

# %%
import matplotlib.pyplot as plot

plot.plot(history.history['accuracy'])
plot.plot(history.history['val_accuracy'])
plot.title('Model accuracy')
plot.ylabel('Accuracy')
plot.xlabel('Epoch')
plot.legend(['Train', 'validation'], loc='upper left')
plot.show()

plot.plot(history.history['loss'])
plot.plot(history.history['val_loss'])
plot.title('Model loss')
plot.ylabel('Loss')
plot.xlabel('Epoch')
plot.legend(['Train', 'validation'], loc='upper left')
plot.show()

# %%
model5.save("DCNN_modi1.h5")

# %% [markdown]
# # Dataset, Train/Validation/Test로 다시 분류
# - 전체 데이터의 20%를 Test 자료로 사용
# - 나머지 자료의 80%를 Train, 20%를 Validation 자료로 사용

# %%
df
# Out:
#        emotion                                             pixels
# 0          5.0  10 8 7 9 10 21 25 37 39 34 45 82 82 82 88 93 9...
# 1          5.0  69 78 83 92 97 107 124 119 58 32 62 79 106 157...
# 2          5.0  219 217 218 218 224 151 59 75 51 50 107 163 14...
# 3          5.0  254 253 255 254 255 255 250 101 33 54 73 74 64...
# 4          5.0  99 98 82 78 69 56 53 55 51 52 58 67 83 110 118...
# ...        ...                                                ...
# 20292      6.0  47 53 84 119 93 62 51 56 52 56 56 56 57 57 57 ...
# 20293      6.0  30 23 25 21 28 36 50 77 97 104 110 113 119 127...
# 20294      6.0  42 31 6 6 0 3 3 0 0 0 10 71 133 169 187 198 20...
# 20295      6.0  220 221 195 129 122 128 131 123 126 135 140 14...
# 20296      6.0  118 24 15 16 34 31 56 85 87 89 90 103 106 112 ...
#
# [20297 rows x 2 columns]

# %% [markdown]
# - X : pixels
# - Y : emotion

# %%
X_train, X_test, y_train, y_test = train_test_split(img_array, img_labels,
                                                    shuffle=True, stratify=img_labels,
                                                    test_size=0.2, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((16237, 48, 48, 1), (4060, 48, 48, 1), (16237, 4), (4060, 4))

# %%
X, X_test, Y, y_test = train_test_split(img_array, img_labels,
                                                    shuffle=True, stratify=img_labels,
                                                    test_size=0.2, random_state=42)
X.shape, X_test.shape, Y.shape, y_test.shape
# Out:
# ((16237, 48, 48, 1), (4060, 48, 48, 1), (16237, 4), (4060, 4))

# %%
x_train, x_val, y_train, y_val = train_test_split(X, Y, shuffle=True, 
                                                    test_size=0.2, random_state=42)
x_train.shape, x_val.shape, y_train.shape, y_val.shape
# Out:
# ((12989, 48, 48, 1), (3248, 48, 48, 1), (12989, 4), (3248, 4))

# %% [markdown]
# - train : 12989
# - validation : 3248
# - test: 4060

# %%
img_width = x_train.shape[1]
img_height = x_train.shape[2]
img_depth = x_train.shape[3]
num_classes = y_train.shape[1]

# %%
x_train = x_train / 255.
x_val = x_val / 255.

# %%
X_test=X_test/255.

# %%
train_datagen = ImageDataGenerator(rotation_range=15,width_shift_range=0.15,height_shift_range=0.15,
    shear_range=0.15,zoom_range=0.15,horizontal_flip=True)
train_datagen.fit(x_train)

# %%
def build_net5(optim):
            net = Sequential(name='DCNN')

            net.add(Conv2D(filters=128, kernel_size=(5,5),input_shape=(img_width, img_height, img_depth),activation='elu',
                           padding='same',kernel_initializer='he_normal', name='conv2d_1'))
            net.add(BatchNormalization(name='batchnorm_1'))
            net.add(Conv2D(filters=128, kernel_size=(5,5),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_2'))
            net.add(BatchNormalization(name='batchnorm_2'))
            net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_1'))
            net.add(Dropout(0.3, name='dropout_1'))

            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_3'))
            net.add(BatchNormalization(name='batchnorm_3'))
            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_4'))
            net.add(BatchNormalization(name='batchnorm_4'))
            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_7'))
            net.add(BatchNormalization(name='batchnorm_7'))           
            net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_2'))
            net.add(Dropout(0.4, name='dropout_2'))

            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_5'))
            net.add(BatchNormalization(name='batchnorm_5'))
            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_6'))
            net.add(BatchNormalization(name='batchnorm_6'))
            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_8'))
            net.add(BatchNormalization(name='batchnorm_8'))            
            net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_3'))
            net.add(Dropout(0.4, name='dropout_3'))

            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_9'))
            net.add(BatchNormalization(name='batchnorm_10'))
            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_10'))
            net.add(BatchNormalization(name='batchnorm_11'))
            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='relu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_11'))
            net.add(BatchNormalization(name='batchnorm_12'))            
            net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_4'))
            net.add(Dropout(0.5, name='dropout_4'))            


            net.add(Flatten(name='flatten'))
            net.add(Dense(128,activation='elu',kernel_initializer='he_normal',name='dense_1'))
            net.add(BatchNormalization(name='batchnorm_9'))
            net.add(Dropout(0.6, name='dropout_5'))
            net.add(Dense(num_classes,activation='softmax',name='out_layer'))

            net.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

            net.summary()

            
            return net

# %%
early_stopping = EarlyStopping(monitor='val_accuracy',min_delta=0.00005,patience=10,verbose=1,
    restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_accuracy',factor=0.5,patience=7,min_lr=1e-7,verbose=1)

callbacks = [early_stopping,lr_scheduler]

# %%
train_datagen = ImageDataGenerator(rotation_range=15,width_shift_range=0.15,height_shift_range=0.15,
    shear_range=0.15,zoom_range=0.15,horizontal_flip=True)
train_datagen.fit(x_train)

# %%
batch_size = 64 
epochs = 100
optims = [optimizers.Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, name='Nadam')
          ,optimizers.Adam(0.001)]

# %%
model = build_net5(optims[1]) 
history = model.fit(train_datagen.flow(x_train, y_train, batch_size=batch_size),validation_data=(x_val, y_val),
    steps_per_epoch=len(x_train) / batch_size,epochs=epochs,callbacks=callbacks)
# Out:
# Model: "DCNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 48, 48, 128)       3328
#
#  batchnorm_1 (BatchNormaliza  (None, 48, 48, 128)      512
#  tion)
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       409728
#
#  batchnorm_2 (BatchNormaliza  (None, 48, 48, 128)      512
#  tion)
#
#  maxpool2d_1 (MaxPooling2D)  (None, 24, 24, 128)       0
#
#  dropout_1 (Dropout)         (None, 24, 24, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 256)       295168
#
#  batchnorm_3 (BatchNormaliza  (None, 24, 24, 256)      1024
#  tion)
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 256)       590080
#
#  batchnorm_4 (BatchNormaliza  (None, 24, 24, 256)      1024
#  tion)
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 256)       590080
#
#  batchnorm_7 (BatchNormaliza  (None, 24, 24, 256)      1024
#  tion)
#
#  maxpool2d_2 (MaxPooling2D)  (None, 12, 12, 256)       0
#
#  dropout_2 (Dropout)         (None, 12, 12, 256)       0
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 256)       590080
#
#  batchnorm_5 (BatchNormaliza  (None, 12, 12, 256)      1024
#  tion)
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 256)       590080
#
#  batchnorm_6 (BatchNormaliza  (None, 12, 12, 256)      1024
#  tion)
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 256)       590080
#
#  batchnorm_8 (BatchNormaliza  (None, 12, 12, 256)      1024
#  tion)
#
#  maxpool2d_3 (MaxPooling2D)  (None, 6, 6, 256)         0
#
#  dropout_3 (Dropout)         (None, 6, 6, 256)         0
#
#  conv2d_9 (Conv2D)           (None, 6, 6, 256)         590080
#
#  batchnorm_10 (BatchNormaliz  (None, 6, 6, 256)        1024
#  ation)
#
#  conv2d_10 (Conv2D)          (None, 6, 6, 256)         590080
#
#  batchnorm_11 (BatchNormaliz  (None, 6, 6, 256)        1024
#  ation)
#
#  conv2d_11 (Conv2D)          (None, 6, 6, 256)         590080
#
#  batchnorm_12 (BatchNormaliz  (None, 6, 6, 256)        1024
#  ation)
#
#  maxpool2d_4 (MaxPooling2D)  (None, 3, 3, 256)         0
#
#  dropout_4 (Dropout)         (None, 3, 3, 256)         0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense_1 (Dense)             (None, 128)               295040
#
#  batchnorm_9 (BatchNormaliza  (None, 128)              512
#  tion)
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  out_layer (Dense)           (None, 4)                 516
#
# =================================================================
# Total params: 5,735,172
# Trainable params: 5,729,796
# Non-trainable params: 5,376
# _________________________________________________________________
# Epoch 1/100
# 202/202 [==============================] - 14s 63ms/step - loss: 1.8219 - accuracy: 0.2991 - val_loss: 1.7959 - val_accuracy: 0.2743 - lr: 0.0010
# Epoch 2/100
# 202/202 [==============================] - 13s 62ms/step - loss: 1.4138 - accuracy: 0.3635 - val_loss: 1.1916 - val_accuracy: 0.4612 - lr: 0.0010
# Epoch 3/100
# 202/202 [==============================] - 13s 62ms/step - loss: 1.2311 - accuracy: 0.4435 - val_loss: 1.0511 - val_accuracy: 0.5302 - lr: 0.0010
# Epoch 4/100
# 202/202 [==============================] - 12s 61ms/step - loss: 1.0845 - accuracy: 0.5262 - val_loss: 0.9699 - val_accuracy: 0.5770 - lr: 0.0010
# Epoch 5/100
# 202/202 [==============================] - 12s 61ms/step - loss: 0.9721 - accuracy: 0.5769 - val_loss: 0.9387 - val_accuracy: 0.6102 - lr: 0.0010
# Epoch 6/100
# 202/202 [==============================] - 13s 62ms/step - loss: 0.8780 - accuracy: 0.6287 - val_loss: 0.7654 - val_accuracy: 0.6817 - lr: 0.0010
# Epoch 7/100
# 202/202 [==============================] - 13s 62ms/step - loss: 0.8218 - accuracy: 0.6587 - val_loss: 0.8933 - val_accuracy: 0.6496 - lr: 0.0010
# Epoch 8/100
# 202/202 [==============================] - 13s 62ms/step - loss: 0.7744 - accuracy: 0.6821 - val_loss: 0.7370 - val_accuracy: 0.7047 - lr: 0.0010
# Epoch 9/100
# 202/202 [==============================] - 13s 62ms/step - loss: 0.7464 - accuracy: 0.6934 - val_loss: 0.7468 - val_accuracy: 0.7118 - lr: 0.0010
# Epoch 10/100
# 202/202 [==============================] - 13s 62ms/step - loss: 0
100
# 202/202 [==============================] - 13s 62ms/step - loss: 0.1930 - accuracy: 0.9315 - val_loss: 0.6708 - val_accuracy: 0.8214 - lr: 1.2500e-04
# Epoch 69/100
# 202/202 [==============================] - 13s 62ms/step - loss: 0.1887 - accuracy: 0.9329 - val_loss: 0.6420 - val_accuracy: 0.8236 - lr: 1.2500e-04
# Epoch 70/100
# 202/202 [==============================] - 13s 62ms/step - loss: 0.1969 - accuracy: 0.9328 - val_loss: 0.6606 - val_accuracy: 0.8227 - lr: 1.2500e-04
# Epoch 71/100
# 203/202 [==============================] - ETA: 0s - loss: 0.1818 - accuracy: 0.9343
# Epoch 71: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 202/202 [==============================] - 12s 61ms/step - loss: 0.1818 - accuracy: 0.9343 - val_loss: 0.6952 - val_accuracy: 0.8208 - lr: 1.2500e-04
# Epoch 72/100
# 202/202 [==============================] - 13s 62ms/step - loss: 0.1781 - accuracy: 0.9360 - val_loss: 0.6816 - val_accuracy: 0.8187 - lr: 6.2500e-05
# Epoch 73/100
# 202/202 [==============================] - 13s 62ms/step - loss: 0.1828 - accuracy: 0.9369 - val_loss: 0.6705 - val_accuracy: 0.8180 - lr: 6.2500e-05
# Epoch 74/100
# 203/202 [==============================] - ETA: 0s - loss: 0.1753 - accuracy: 0.9383Restoring model weights from the end of the best epoch: 64.
# 202/202 [==============================] - 13s 62ms/step - loss: 0.1753 - accuracy: 0.9383 - val_loss: 0.6872 - val_accuracy: 0.8236 - lr: 6.2500e-05
# Epoch 74: early stopping

# %%
result= model.evaluate(x_val, y_val)
# Out:
# 102/102 [==============================] - 1s 12ms/step - loss: 0.6378 - accuracy: 0.8236

# %%
result= model.evaluate(X_test, y_test)
# Out:
# 127/127 [==============================] - 2s 12ms/step - loss: 0.6327 - accuracy: 0.8143

# %%
model.save("/content/drive/MyDrive/final/data/DCNNmodel.h5")

# %%
def build_net(optim):
            net = Sequential(name='DCNN')

            net.add(Conv2D(filters=256,kernel_size=(5,5),input_shape=(img_width, img_height, img_depth),activation='elu',
                           padding='same',kernel_initializer='he_normal', name='conv2d_1'))
            net.add(BatchNormalization(name='batchnorm_1'))
            net.add(Conv2D(filters=128,kernel_size=(5,5),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_2'))
            net.add(BatchNormalization(name='batchnorm_2'))
            net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_1'))
            net.add(Dropout(0.4, name='dropout_1'))
            net.add(Conv2D(filters=128,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_3'))
            net.add(BatchNormalization(name='batchnorm_3'))
            net.add(Conv2D(filters=128,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_4'))
            net.add(BatchNormalization(name='batchnorm_4'))
            net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_2'))
            net.add(Dropout(0.4, name='dropout_2'))
            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_5'))
            net.add(BatchNormalization(name='batchnorm_5'))
            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_6'))
            net.add(BatchNormalization(name='batchnorm_6'))
            net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_3'))
            net.add(Dropout(0.5, name='dropout_3'))
            net.add(Flatten(name='flatten'))
            net.add(Dense(128,activation='elu',kernel_initializer='he_normal',name='dense_1'))
            net.add(BatchNormalization(name='batchnorm_7'))
            net.add(Dropout(0.6, name='dropout_4'))
            net.add(Dense(num_classes,activation='softmax',name='out_layer'))

            net.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

            net.summary()

            
            return net

# %%
model = build_net(optims[1]) 
history = model.fit(train_datagen.flow(x_train, y_train, batch_size=batch_size),validation_data=(x_val, y_val),
    steps_per_epoch=len(x_train) / batch_size,epochs=epochs,callbacks=callbacks)
# Out:
# Model: "DCNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 48, 48, 256)       6656
#
#  batchnorm_1 (BatchNormaliza  (None, 48, 48, 256)      1024
#  tion)
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       819328
#
#  batchnorm_2 (BatchNormaliza  (None, 48, 48, 128)      512
#  tion)
#
#  maxpool2d_1 (MaxPooling2D)  (None, 24, 24, 128)       0
#
#  dropout_1 (Dropout)         (None, 24, 24, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)       147584
#
#  batchnorm_3 (BatchNormaliza  (None, 24, 24, 128)      512
#  tion)
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 128)       147584
#
#  batchnorm_4 (BatchNormaliza  (None, 24, 24, 128)      512
#  tion)
#
#  maxpool2d_2 (MaxPooling2D)  (None, 12, 12, 128)       0
#
#  dropout_2 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 256)       295168
#
#  batchnorm_5 (BatchNormaliza  (None, 12, 12, 256)      1024
#  tion)
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 256)       590080
#
#  batchnorm_6 (BatchNormaliza  (None, 12, 12, 256)      1024
#  tion)
#
#  maxpool2d_3 (MaxPooling2D)  (None, 6, 6, 256)         0
#
#  dropout_3 (Dropout)         (None, 6, 6, 256)         0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense_1 (Dense)             (None, 128)               1179776
#
#  batchnorm_7 (BatchNormaliza  (None, 128)              512
#  tion)
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  out_layer (Dense)           (None, 4)                 516
#
# =================================================================
# Total params: 3,191,812
# Trainable params: 3,189,252
# Non-trainable params: 2,560
# _________________________________________________________________
# Epoch 1/100
# 202/202 [==============================] - 15s 60ms/step - loss: 1.8007 - accuracy: 0.3197 - val_loss: 1.2648 - val_accuracy: 0.4218 - lr: 0.0010
# Epoch 2/100
# 202/202 [==============================] - 11s 56ms/step - loss: 1.3780 - accuracy: 0.3856 - val_loss: 1.1361 - val_accuracy: 0.5028 - lr: 0.0010
# Epoch 3/100
# 202/202 [==============================] - 11s 52ms/step - loss: 1.2298 - accuracy: 0.4470 - val_loss: 1.0283 - val_accuracy: 0.5585 - lr: 0.0010
# Epoch 4/100
# 202/202 [==============================] - 10s 50ms/step - loss: 1.1323 - accuracy: 0.5034 - val_loss: 1.0139 - val_accuracy: 0.5637 - lr: 0.0010
# Epoch 5/100
# 202/202 [==============================] - 10s 50ms/step - loss: 1.0569 - accuracy: 0.5399 - val_loss: 0.9118 - val_accuracy: 0.5973 - lr: 0.0010
# Epoch 6/100
# 202/202 [==============================] - 11s 52ms/step - loss: 0.9745 - accuracy: 0.5853 - val_loss: 0.8173 - val_accuracy: 0.6552 - lr: 0.0010
# Epoch 7/100
# 202/202 [==============================] - 11s 53ms/step - loss: 0.9057 - accuracy: 0.6164 - val_loss: 0.8519 - val_accuracy: 0.6592 - lr: 0.0010
# Epoch 8/100
# 202/202 [==============================] - 10s 50ms/step - loss: 0.8513 - accuracy: 0.6439 - val_loss: 0.7981 - val_accuracy: 0.6881 - lr: 0.0010
# Epoch 9/100
# 202/202 [==============================] - 10s 51ms/step - loss: 0.8133 - accuracy: 0.6616 - val_loss: 0.7823 - val_accuracy: 0.6949 - lr: 0.0010
# Epoch 10/100
# 202/202 [==============================] - 10s 50ms/step - loss: 0.7819 - accuracy: 0.6789 - val_loss: 0.7528 - val_accuracy: 0.7014 - lr: 0.0010
# Epoch 11/100
# 202/202 [==============================] - 11s 52ms/step - loss: 0.7620 - accuracy: 0.6830 - val_loss: 0.6944 - val_accuracy: 0.7238 - lr: 0.0010
# Epoch 12/100
# 202/202 [==============================] - 11s 52ms/step - loss: 0.7422 - accuracy: 0.6994 - val_loss: 0.6354 - val_accuracy: 0.7383 - lr: 0.0010
# Epoch 13/100
# 202/202 [==============================] - 10s 50ms/step - loss: 0.7201 - accuracy: 0.7108 - val_loss: 0.7000 - val_accuracy: 0.7281 - lr: 0.0010
# Epoch 14/100
# 202/202 [==============================] - 10s 50ms/step - loss: 0.7073 - accuracy: 0.7110 - val_loss: 0.6158 - val_accuracy: 0.7460 - lr: 0.0010
# Epoch 15/100
# 202/202 [==============================] - 11s 52ms/step - loss: 0
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 202/202 [==============================] - 10s 50ms/step - loss: 0.5119 - accuracy: 0.8024 - val_loss: 0.5709 - val_accuracy: 0.7857 - lr: 0.0010
# Epoch 43/100
# 202/202 [==============================] - 11s 52ms/step - loss: 0.4856 - accuracy: 0.8156 - val_loss: 0.5092 - val_accuracy: 0.8039 - lr: 5.0000e-04
# Epoch 44/100
# 202/202 [==============================] - 11s 52ms/step - loss: 0.4743 - accuracy: 0.8187 - val_loss: 0.5013 - val_accuracy: 0.8042 - lr: 5.0000e-04
# Epoch 45/100
# 202/202 [==============================] - 10s 51ms/step - loss: 0.4636 - accuracy: 0.8198 - val_loss: 0.5208 - val_accuracy: 0.8011 - lr: 5.0000e-04
# Epoch 46/100
# 202/202 [==============================] - 10s 51ms/step - loss: 0.4671 - accuracy: 0.8217 - val_loss: 0.5519 - val_accuracy: 0.7885 - lr: 5.0000e-04
# Epoch 47/100
# 202/202 [==============================] - 10s 51ms/step - loss: 0.4546 - accuracy: 0.8219 - val_loss: 0.5165 - val_accuracy: 0.8026 - lr: 5.0000e-04
# Epoch 48/100
# 202/202 [==============================] - 10s 51ms/step - loss: 0.4513 - accuracy: 0.8231 - val_loss: 0.5475 - val_accuracy: 0.7919 - lr: 5.0000e-04
# Epoch 49/100
# 202/202 [==============================] - 10s 51ms/step - loss: 0.4527 - accuracy: 0.8252 - val_loss: 0.5351 - val_accuracy: 0.7968 - lr: 5.0000e-04
# Epoch 50/100
# 202/202 [==============================] - 10s 50ms/step - loss: 0.4540 - accuracy: 0.8257 - val_loss: 0.5322 - val_accuracy: 0.7999 - lr: 5.0000e-04
# Epoch 51/100
# 202/202 [==============================] - 11s 52ms/step - loss: 0.4481 - accuracy: 0.8287 - val_loss: 0.5054 - val_accuracy: 0.8100 - lr: 5.0000e-04
# Epoch 52/100
# 202/202 [==============================] - 11s 52ms/step - loss: 0.4382 - accuracy: 0.8279 - val_loss: 0.5318 - val_accuracy: 0.7980 - lr: 5.0000e-04
# Epoch 53/100
# 202/202 [==============================] - 10s 50ms/step - loss: 0.4392 - accuracy: 0.8318 - val_loss: 0.5282 - val_accuracy: 0.8008 - lr: 5.0000e-04
# Epoch 54/100
# 202/202 [==============================] - 10s 50ms/step - loss: 0.4304 - accuracy: 0.8329 - val_loss: 0.5275 - val_accuracy: 0.7937 - lr: 5.0000e-04
# Epoch 55/100
# 202/202 [==============================] - 10s 50ms/step - loss: 0.4341 - accuracy: 0.8330 - val_loss: 0.5901 - val_accuracy: 0.7805 - lr: 5.0000e-04
# Epoch 56/100
# 202/202 [==============================] - 10s 51ms/step - loss: 0.4338 - accuracy: 0.8337 - val_loss: 0.5392 - val_accuracy: 0.8002 - lr: 5.0000e-04
# Epoch 57/100
# 202/202 [==============================] - 10s 50ms/step - loss: 0.4303 - accuracy: 0.8299 - val_loss: 0.5267 - val_accuracy: 0.8014 - lr: 5.0000e-04
# Epoch 58/100
# 202/202 [============================>.] - ETA: 0s - loss: 0.4293 - accuracy: 0.8326
# Epoch 58: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 202/202 [==============================] - 10s 50ms/step - loss: 0.4290 - accuracy: 0.8327 - val_loss: 0.5310 - val_accuracy: 0.8076 - lr: 5.0000e-04
# Epoch 59/100
# 202/202 [==============================] - 11s 52ms/step - loss: 0.4109 - accuracy: 0.8428 - val_loss: 0.5270 - val_accuracy: 0.8020 - lr: 2.5000e-04
# Epoch 60/100
# 202/202 [==============================] - 11s 52ms/step - loss: 0.4002 - accuracy: 0.8467 - val_loss: 0.5398 - val_accuracy: 0.8033 - lr: 2.5000e-04
# Epoch 61/100
# 202/202 [============================>.] - ETA: 0s - loss: 0.4002 - accuracy: 0.8484Restoring model weights from the end of the best epoch: 51.
# 202/202 [==============================] - 10s 51ms/step - loss: 0.4011 - accuracy: 0.8480 - val_loss: 0.5472 - val_accuracy: 0.7996 - lr: 2.5000e-04
# Epoch 61: early stopping

# %%
result= model.evaluate(x_val, y_val)
# Out:
# 102/102 [==============================] - 1s 12ms/step - loss: 0.5054 - accuracy: 0.8100

# %%
result= model.evaluate(X_test, y_test)
# Out:
# 127/127 [==============================] - 2s 13ms/step - loss: 0.5114 - accuracy: 0.8052

# %% [markdown]
# # 예측하기(Test)

# %%
df
# Out:
#        emotion                                             pixels
# 0          5.0  10 8 7 9 10 21 25 37 39 34 45 82 82 82 88 93 9...
# 1          5.0  69 78 83 92 97 107 124 119 58 32 62 79 106 157...
# 2          5.0  219 217 218 218 224 151 59 75 51 50 107 163 14...
# 3          5.0  254 253 255 254 255 255 250 101 33 54 73 74 64...
# 4          5.0  99 98 82 78 69 56 53 55 51 52 58 67 83 110 118...
# ...        ...                                                ...
# 20292      6.0  47 53 84 119 93 62 51 56 52 56 56 56 57 57 57 ...
# 20293      6.0  30 23 25 21 28 36 50 77 97 104 110 113 119 127...
# 20294      6.0  42 31 6 6 0 3 3 0 0 0 10 71 133 169 187 198 20...
# 20295      6.0  220 221 195 129 122 128 131 123 126 135 140 14...
# 20296      6.0  118 24 15 16 34 31 56 85 87 89 90 103 106 112 ...
#
# [20297 rows x 2 columns]

# %%
img_array = df.pixels.apply(lambda x: np.array(x.split(' ')).reshape(48,48,1).astype('float32'))
img_array = np.stack(img_array, axis=0)

# %%
le = LabelEncoder()
img_labels = le.fit_transform(df['emotion'])
img_labels = np_utils.to_categorical(img_labels)
img_labels.shape
# Out:
# (20297, 4)

# %%
le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(le_name_mapping)
# Out:
# {3.0: 0, 4.0: 1, 5.0: 2, 6.0: 3}

# %%
X_train, X_test, y_train, y_test = train_test_split(img_array, img_labels,
                                                    shuffle=True, stratify=img_labels,
                                                    test_size=0.2, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((16237, 48, 48, 1), (4060, 48, 48, 1), (16237, 4), (4060, 4))

# %%
X, X_test, Y, y_test = train_test_split(img_array, img_labels,
                                                    shuffle=True, stratify=img_labels,
                                                    test_size=0.2, random_state=42)
X.shape, X_test.shape, Y.shape, y_test.shape
# Out:
# ((16237, 48, 48, 1), (4060, 48, 48, 1), (16237, 4), (4060, 4))

# %%
x_train, x_val, y_train, y_val = train_test_split(X, Y, shuffle=True, 
                                                    test_size=0.2, random_state=42)
x_train.shape, x_val.shape, y_train.shape, y_val.shape
# Out:
# ((12989, 48, 48, 1), (3248, 48, 48, 1), (12989, 4), (3248, 4))

# %%
img_width = X_train.shape[1]
img_height = X_train.shape[2]
num_classes = y_train.shape[1]
img_depth = X_train.shape[3]

# %%
x_train = x_train / 255.
x_val = x_val / 255.
X_test=X_test/255.

# %%
def build_net(optim):
            net = Sequential(name='DCNN')

            net.add(Conv2D(filters=256,kernel_size=(5,5),input_shape=(img_width, img_height,img_depth),activation='elu',
                           padding='same',kernel_initializer='he_normal', name='conv2d_1'))
            net.add(BatchNormalization(name='batchnorm_1'))
            net.add(Conv2D(filters=128,kernel_size=(5,5),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_2'))
            net.add(BatchNormalization(name='batchnorm_2'))
            net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_1'))
            net.add(Dropout(0.4, name='dropout_1'))
            net.add(Conv2D(filters=128,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_3'))
            net.add(BatchNormalization(name='batchnorm_3'))
            net.add(Conv2D(filters=128,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_4'))
            net.add(BatchNormalization(name='batchnorm_4'))
            net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_2'))
            net.add(Dropout(0.4, name='dropout_2'))
            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_5'))
            net.add(BatchNormalization(name='batchnorm_5'))
            net.add(Conv2D(filters=256,kernel_size=(3,3),activation='elu',padding='same',kernel_initializer='he_normal',
                        name='conv2d_6'))
            net.add(BatchNormalization(name='batchnorm_6'))
            net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_3'))
            net.add(Dropout(0.5, name='dropout_3'))
            net.add(Flatten(name='flatten'))
            net.add(Dense(128,activation='elu',kernel_initializer='he_normal',name='dense_1'))
            net.add(BatchNormalization(name='batchnorm_7'))
            net.add(Dropout(0.6, name='dropout_4'))
            net.add(Dense(num_classes,activation='softmax',name='out_layer'))

            net.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

            net.summary()

            
            return net

# %%
train_datagen = ImageDataGenerator(rotation_range=15,width_shift_range=0.15,height_shift_range=0.15,
    shear_range=0.15,zoom_range=0.15,horizontal_flip=True)
train_datagen.fit(x_train)

# %%
early_stopping = EarlyStopping(monitor='val_accuracy',min_delta=0.00005,patience=10,verbose=1,
    restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_accuracy',factor=0.5,patience=7,min_lr=1e-7,verbose=1)

callbacks = [early_stopping,lr_scheduler]

# %%
batch_size = 64 
epochs = 100
optims = [optimizers.Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, name='Nadam')
          ,optimizers.Adam(0.001)]

# %%
model = build_net(optims[1]) 
history = model.fit(train_datagen.flow(x_train, y_train, batch_size=batch_size),validation_data=(x_val, y_val),
    steps_per_epoch=len(x_train) / batch_size,epochs=epochs,callbacks=callbacks)
# Out:
# Model: "DCNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 48, 48, 256)       6656
#
#  batchnorm_1 (BatchNormaliza  (None, 48, 48, 256)      1024
#  tion)
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       819328
#
#  batchnorm_2 (BatchNormaliza  (None, 48, 48, 128)      512
#  tion)
#
#  maxpool2d_1 (MaxPooling2D)  (None, 24, 24, 128)       0
#
#  dropout_1 (Dropout)         (None, 24, 24, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)       147584
#
#  batchnorm_3 (BatchNormaliza  (None, 24, 24, 128)      512
#  tion)
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 128)       147584
#
#  batchnorm_4 (BatchNormaliza  (None, 24, 24, 128)      512
#  tion)
#
#  maxpool2d_2 (MaxPooling2D)  (None, 12, 12, 128)       0
#
#  dropout_2 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 256)       295168
#
#  batchnorm_5 (BatchNormaliza  (None, 12, 12, 256)      1024
#  tion)
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 256)       590080
#
#  batchnorm_6 (BatchNormaliza  (None, 12, 12, 256)      1024
#  tion)
#
#  maxpool2d_3 (MaxPooling2D)  (None, 6, 6, 256)         0
#
#  dropout_3 (Dropout)         (None, 6, 6, 256)         0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense_1 (Dense)             (None, 128)               1179776
#
#  batchnorm_7 (BatchNormaliza  (None, 128)              512
#  tion)
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  out_layer (Dense)           (None, 4)                 516
#
# =================================================================
# Total params: 3,191,812
# Trainable params: 3,189,252
# Non-trainable params: 2,560
# _________________________________________________________________
# Epoch 1/100
# 202/202 [==============================] - 22s 57ms/step - loss: 1.8252 - accuracy: 0.3086 - val_loss: 1.4810 - val_accuracy: 0.3959 - lr: 0.0010
# Epoch 2/100
# 202/202 [==============================] - 11s 56ms/step - loss: 1.4098 - accuracy: 0.3802 - val_loss: 1.1675 - val_accuracy: 0.5058 - lr: 0.0010
# Epoch 3/100
# 202/202 [==============================] - 11s 53ms/step - loss: 1.2616 - accuracy: 0.4374 - val_loss: 1.0534 - val_accuracy: 0.5514 - lr: 0.0010
# Epoch 4/100
# 202/202 [==============================] - 10s 51ms/step - loss: 1.1519 - accuracy: 0.4967 - val_loss: 0.9941 - val_accuracy: 0.5659 - lr: 0.0010
# Epoch 5/100
# 202/202 [==============================] - 10s 51ms/step - loss: 1.0498 - accuracy: 0.5428 - val_loss: 0.9154 - val_accuracy: 0.6213 - lr: 0.0010
# Epoch 6/100
# 202/202 [==============================] - 10s 51ms/step - loss: 0
100
# 202/202 [==============================] - 10s 51ms/step - loss: 0.3771 - accuracy: 0.8581 - val_loss: 0.5330 - val_accuracy: 0.8057 - lr: 1.2500e-04
# Epoch 74/100
# 202/202 [============================>.] - ETA: 0s - loss: 0.3792 - accuracy: 0.8562
# Epoch 74: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 202/202 [==============================] - 10s 51ms/step - loss: 0.3786 - accuracy: 0.8563 - val_loss: 0.5278 - val_accuracy: 0.8085 - lr: 1.2500e-04
# Epoch 75/100
# 202/202 [==============================] - 10s 51ms/step - loss: 0.3646 - accuracy: 0.8608 - val_loss: 0.5261 - val_accuracy: 0.8097 - lr: 6.2500e-05
# Epoch 76/100
# 202/202 [==============================] - 10s 51ms/step - loss: 0.3708 - accuracy: 0.8586 - val_loss: 0.5229 - val_accuracy: 0.8073 - lr: 6.2500e-05
# Epoch 77/100
# 202/202 [============================>.] - ETA: 0s - loss: 0.3699 - accuracy: 0.8610Restoring model weights from the end of the best epoch: 67.
# 202/202 [==============================] - 10s 51ms/step - loss: 0.3703 - accuracy: 0.8607 - val_loss: 0.5261 - val_accuracy: 0.8119 - lr: 6.2500e-05
# Epoch 77: early stopping

# %%
result= model.evaluate(X_test, y_test)
# Out:
# 127/127 [==============================] - 1s 11ms/step - loss: 0.5386 - accuracy: 0.8074

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])

# %%
predictions = probability_model.predict(X_test)

# %%
predictions[999]
# Out:
# array([0.17881972, 0.19244619, 0.44895148, 0.17978257], dtype=float32)

# %%
 np.argmax(predictions[999])
# Out:
# 2

# %% [markdown]
# ## 이미지 테스트

# %%
from PIL import Image
import imageio
from matplotlib import cm

# %%
sample = np.reshape(X_test[600]*255, (48,48))
imageio.imwrite('/content/drive/MyDrive/data/AIHUB/004.jpg',sample)
sample=cv2.imread('/content/drive/MyDrive/data/AIHUB/004.jpg')
cv2_imshow(sample)
# Out:
# WARNING:root:Lossy conversion from float32 to uint8. Range [22.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FADF7E521D0>

# %%
for i in range(50):
  if y_test.tolist()[i]==[0.,0.,0.,1.]:
    print(i)
# Out:
# 3
# 4
# 11
# 15
# 20
# 23
# 24
# 29
# 34
# 39
# 47

# %%
img=np.reshape(X_test[3]*255, (48,48))
imageio.imwrite(f'/content/drive/MyDrive/data/AIHUB/test3.jpg',img)
test3=cv2.imread('/content/drive/MyDrive/data/AIHUB/test3.jpg')
cv2_imshow(test3)
# Out:
# WARNING:root:Lossy conversion from float32 to uint8. Range [13.0, 247.0]. Convert image to uint8 prior to saving to suppress this warning.
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FADF26E0AD0>

# %%
for i in range(50):
  if y_test.tolist()[i]==[0.,0.,1.,0.]:
    print(i)
# Out:
# 13
# 17
# 31
# 36
# 37
# 42
# 43
# 45
# 46

# %%
for i in range(50):
  if y_test.tolist()[i]==[0.,1.,0.,0.]:
    print(i)
# Out:
# 0
# 1
# 2
# 5
# 6
# 12
# 14
# 18
# 22
# 27
# 33
# 38

# %%
for i in range(50):
  if y_test.tolist()[i]==[1.,0.,0.,0.]:
    print(i)
# Out:
# 7
# 8
# 9
# 10
# 16
# 19
# 21
# 25
# 26
# 28
# 30
# 32
# 35
# 40
# 41
# 44
# 48
# 49

# %%
def testImg_save(n,num):
  img=np.reshape(X_test[n]*255, (48,48))
  imageio.imwrite(f'/content/drive/MyDrive/data/AIHUB/test{num}.jpg',img)

# %% [markdown]
# ## 샘플이미지 추출

# %%
testImg_save(7,'7')
testImg_save(8,'8')
testImg_save(12,'12')
testImg_save(14,'14')
testImg_save(31,'31')
testImg_save(36,'36')
testImg_save(20,'20')
testImg_save(23,'23')

# %%
testImg_save(28,'28')
testImg_save(44,'44')
testImg_save(27,'27')
testImg_save(33,'33')
testImg_save(45,'45')
testImg_save(46,'46')
testImg_save(47,'47')
testImg_save(39,'39')

# %%
test_img7=cv2.imread('/content/drive/MyDrive/data/AIHUB/test07.jpg')
test_img8=cv2.imread('/content/drive/MyDrive/data/AIHUB/test08.jpg')
test_img28=cv2.imread('/content/drive/MyDrive/data/AIHUB/test28.jpg')
test_img44=cv2.imread('/content/drive/MyDrive/data/AIHUB/test44.jpg')
test_img12=cv2.imread('/content/drive/MyDrive/data/AIHUB/test12.jpg')
test_img14=cv2.imread('/content/drive/MyDrive/data/AIHUB/test14.jpg')
test_img27=cv2.imread('/content/drive/MyDrive/data/AIHUB/test27.jpg')
test_img33=cv2.imread('/content/drive/MyDrive/data/AIHUB/test33.jpg')
test_img31=cv2.imread('/content/drive/MyDrive/data/AIHUB/test31.jpg')
test_img36=cv2.imread('/content/drive/MyDrive/data/AIHUB/test36.jpg')
test_img45=cv2.imread('/content/drive/MyDrive/data/AIHUB/test45.jpg')
test_img46=cv2.imread('/content/drive/MyDrive/data/AIHUB/test46.jpg')
test_img20=cv2.imread('/content/drive/MyDrive/data/AIHUB/test20.jpg')
test_img23=cv2.imread('/content/drive/MyDrive/data/AIHUB/test23.jpg')
test_img39=cv2.imread('/content/drive/MyDrive/data/AIHUB/test39.jpg')
test_img47=cv2.imread('/content/drive/MyDrive/data/AIHUB/test47.jpg')

# %%
emotion_label = {0 :'happiness' , 1: 'sadness' , 2: 'surprise', 3: 'neutral' }

# %%
predictions[20][2]
# Out:
# 0.1890925

# %%
y_test[20].tolist().index(1.0)
# Out:
# 3

# %%
def plot_image(i):
  global predictions, emotion_label
  true_label = y_test[i].tolist().index(1.0)
  img=cv2.imread(f'/content/drive/MyDrive/data/AIHUB/test{i}.jpg')
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img)

  predicted_label = np.argmax(predictions[i])
  if predicted_label == true_label:
    plt.xlabel("{} {:2.0f}%".format(emotion_label[true_label] ,100*max(predictions[i])),color='b')
  else:
    plt.xlabel("{} {:2.0f}% \n real emotion : {} {:2.0f}%".format(emotion_label[predicted_label] ,100*max(predictions[i]), emotion_label[true_label],100*(predictions[i][true_label]) ),color='r')

# %%
plot_image(7)

# %%
plot_image(8)

# %%
plot_image(28)

# %%
plot_image(44)

# %%
plot_image(3)

# %%
def plot_value_array(i):
  true_label = y_test[i].tolist().index(1.0)
  plt.grid(False)
  plt.xticks(range(4))
  plt.yticks([])
  thisplot = plt.bar(range(4), predictions[i], color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions[i])

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
plot_value_array(28)

# %%
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(44, test_img44)
plt.subplot(1,2,2)
plot_value_array(44)
plt.show()

# %%
num_rows = 4
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
#testlist=[7, 8, 28, 44,12,14,27,33,31,36,45,46,20,23,39,47 ]
testlist=[7,44,28,12,14,27,36,45,46,3,23,20]
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(testlist[i])
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(testlist[i])
plt.tight_layout()
plt.show()
